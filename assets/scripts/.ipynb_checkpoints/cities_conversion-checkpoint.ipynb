# %%
#import dependency
import pandas as pd

# %%
#read csv into pandas 
cities_df = pd.read_csv('cities.csv')
cities_df = cities_df.drop
# Out:
#      Unnamed: 0            City  Cloudiness Country        Date  Humidity  \
# 0             0        Klaksvík          95      FO  1604789124        81
# 1             1       Manokwari          99      ID  1604789124        73
# 2             2  Saint-Philippe           0      RE  1604789124        77
# 3             3           Ancud           0      CL  1604789124        51
# 4             4          Kalush           0      UA  1604788888        86
# ..          ...             ...         ...     ...         ...       ...
# 562         562           Homer          90      US  1604789200       100
# 563         563    Podosinovets          98      RU  1604789200        95
# 564         564       Bagumbong          86      PH  1604789200        88
# 565         565        Impfondo          68      CG  1604789201        97
# 566         566          Nicoya          75      CR  1604789102        88
#
#        Lat     Lng  Max Temp  Wind Speed
# ...

# %%
#convert to html
filepath = 'cities-table2.html'
cities_df = cities_df.to_html(filepath)
